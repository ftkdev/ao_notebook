# %% [markdown]
# <font size = '4'><b>Australian Open Neural Network Model</b></font>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# <font size = '4'><b>Import and Check Database</b></font>

# %%
#Load parsed Australian Open Data
url = "https://raw.githubusercontent.com/ftkdev/ao_scraper_project/master/australian_open/extracts/aodata_final.csv"
df = pd.read_csv(url)

# %%
df.shape
# Out:
# (1872, 47)

# %%
df.head()
# Out:
#   calendar_year  p1_1stserve_pwon  p1_1stserve_success  p1_2ndserve_pwon  \
# 0        [2020]              75.0                108.0              28.0
# 1        [2020]              66.0                 79.0              27.0
# 2        [2020]              40.0                 52.0              15.0
# 3        [2020]              77.0                 97.0              24.0
# 4        [2020]               NaN                  NaN               NaN
#
#    p1_aces  p1_breakpoints_won  p1_doublefaults  p1_max_games_row  \
# 0     13.0                 5.0              5.0               6.0
# 1     12.0                 2.0              4.0               3.0
# 2      5.0                 NaN              5.0               1.0
# 3     27.0                 4.0              5.0               5.0
# 4      NaN                 NaN              NaN               NaN
#
#    p1_max_points_row  p1_servgames_won  ...  player2_3rd_set  player2_4th_set  \
# 0                7.0              18.0  ...                2                6
# 1               13.0              19.0  ...                6                6
# 2                5.0              12.0  ...                6                0
# 3                5.0              20.0  ...                2                7
# 4                NaN               NaN  ...                0                0
#
#    player2_5th_set  player2_country  player2_name  player2_seed  \
# 0                6              SRB         Novak           2.0
# 1                0              AUS          Nick          23.0
# 2                0              DEU     Alexander           7.0
# 3                6              CHE         Roger           3.0
# 4                0              ESP        Adrian           NaN
#
#      player2_surname  player2_total_sets  tournament  tournament_phase
# 0           Djokovic                 3.0        2565             Final
# 1            Kyrgios                 1.0        2565       Round of 16
# 2             Zverev                 3.0        2565       Round of 16
# 3            Federer                 3.0        2565     Quarter-Final
# 4  Menendez-Maceiras                 0.0        2565     Qualification
#
# [5 rows x 47 columns]

# %%
df.columns
# Out:
# Index(['calendar_year', 'p1_1stserve_pwon', 'p1_1stserve_success',
#        'p1_2ndserve_pwon', 'p1_aces', 'p1_breakpoints_won', 'p1_doublefaults',
#        'p1_max_games_row', 'p1_max_points_row', 'p1_servgames_won',
#        'p1_tiebreaks_won', 'p1_total_games_won', 'p1_total_points_won',
#        'p2_1stserve_pwon', 'p2_1stserve_success', 'p2_2ndserve_pwon',
#        'p2_aces', 'p2_breakpoints_won', 'p2_doublefaults', 'p2_max_games_row',
#        'p2_max_points_row', 'p2_servgames_won', 'p2_tiebreaks_won',
#        'p2_total_games_won', 'p2_total_points_won', 'player1_1st_set',
#        'player1_2nd_set', 'player1_3rd_set', 'player1_4th_set',
#        'player1_5th_set', 'player1_country', 'player1_name', 'player1_seed',
#        'player1_surname', 'player1_total_sets', 'player2_1st_set',
#        'player2_2nd_set', 'player2_3rd_set', 'player2_4th_set',
#        'player2_5th_set', 'player2_country', 'player2_name', 'player2_seed',
#        'player2_surname', 'player2_total_sets', 'tournament',
#        'tournament_phase'],
#       dtype='object')

# %%
df = df.reindex(sorted(df.columns), axis=1)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1872 entries, 0 to 1871
# Data columns (total 47 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   calendar_year        1872 non-null   object
#  1   p1_1stserve_pwon     1065 non-null   float64
#  2   p1_1stserve_success  1065 non-null   float64
#  3   p1_2ndserve_pwon     1021 non-null   float64
#  4   p1_aces              1022 non-null   float64
#  5   p1_breakpoints_won   814 non-null    float64
#  6   p1_doublefaults      940 non-null    float64
#  7   p1_max_games_row     1062 non-null   float64
#  8   p1_max_points_row    1065 non-null   float64
#  9   p1_servgames_won     1062 non-null   float64
#  10  p1_tiebreaks_won     0 non-null      float64
#  11  p1_total_games_won   1062 non-null   float64
#  12  p1_total_points_won  1065 non-null   float64
#  13  p2_1stserve_pwon     1065 non-null   float64
#  14  p2_1stserve_success  1065 non-null   float64
#  15  p2_2ndserve_pwon     1021 non-null   float64
#  16  p2_aces              1022 non-null   float64
#  17  p2_breakpoints_won   814 non-null    float64
#  18  p2_doublefaults      940 non-null    float64
#  19  p2_max_games_row     1062 non-null   float64
#  20  p2_max_points_row    1065 non-null   float64
#  21  p2_servgames_won     1062 non-null   float64
#  22  p2_tiebreaks_won     0 non-null      float64
#  23  p2_total_games_won   1062 non-null   float64
#  24  p2_total_points_won  1065 non-null   float64
#  25  player1_1st_set      1872 non-null   int64
#  26  player1_2nd_set      1872 non-null   int64
#  27  player1_3rd_set      1872 non-null   int64
#  28  player1_4th_set      1872 non-null   int64
#  29  player1_5th_set      1872 non-null   int64
#  30  player1_country      1872 non-null   object
#  31  player1_name         1666 non-null   object
#  32  player1_seed         658 non-null    float64
#  33  player1_surname      1666 non-null   object
#  34  player1_total_sets   1867 non-null   float64
#  35  player2_1st_set      1872 non-null   int64
#  36  player2_2nd_set      1872 non-null   int64
#  37  player2_3rd_set      1872 non-null   int64
#  38  player2_4th_set      1872 non-null   int64
#  39  player2_5th_set      1872 non-null   int64
#  40  player2_country      1872 non-null   object
#  41  player2_name         1700 non-null   object
#  42  player2_seed         641 non-null    float64
#  43  player2_surname      1700 non-null   object
#  44  player2_total_sets   1867 non-null   float64
#  45  tournament           1872 non-null   int64
#  46  tournament_phase     1872 non-null   object
# dtypes: float64(28), int64(11), object(8)
# memory usage: 687.5+ KB

# %%
# Fix calendar_year column
df['calendar_year'] = df['calendar_year'].str.replace('[', '', regex=True).str.replace(']', '', regex=True).astype(int)
df['calendar_year']
# Out:
# 0       2020
# 1       2020
# 2       2020
# 3       2020
# 4       2020
#         ...
# 1867    2022
# 1868    2022
# 1869    2022
# 1870    2022
# 1871    2022
# Name: calendar_year, Length: 1872, dtype: int64

# %%
df.columns
# Out:
# Index(['calendar_year', 'p1_1stserve_pwon', 'p1_1stserve_success',
#        'p1_2ndserve_pwon', 'p1_aces', 'p1_breakpoints_won', 'p1_doublefaults',
#        'p1_max_games_row', 'p1_max_points_row', 'p1_servgames_won',
#        'p1_tiebreaks_won', 'p1_total_games_won', 'p1_total_points_won',
#        'p2_1stserve_pwon', 'p2_1stserve_success', 'p2_2ndserve_pwon',
#        'p2_aces', 'p2_breakpoints_won', 'p2_doublefaults', 'p2_max_games_row',
#        'p2_max_points_row', 'p2_servgames_won', 'p2_tiebreaks_won',
#        'p2_total_games_won', 'p2_total_points_won', 'player1_1st_set',
#        'player1_2nd_set', 'player1_3rd_set', 'player1_4th_set',
#        'player1_5th_set', 'player1_country', 'player1_name', 'player1_seed',
#        'player1_surname', 'player1_total_sets', 'player2_1st_set',
#        'player2_2nd_set', 'player2_3rd_set', 'player2_4th_set',
#        'player2_5th_set', 'player2_country', 'player2_name', 'player2_seed',
#        'player2_surname', 'player2_total_sets', 'tournament',
#        'tournament_phase'],
#       dtype='object')

# %% [markdown]
# <font size = '4'><b>Prepare the Database</b></font>

# %%
#Create dependent variable y (winner)
conditions = [
    (df['player1_total_sets'] > df['player2_total_sets']),
    (df['player1_total_sets'] < df['player2_total_sets']),
    (df['player1_total_sets'] == df['player2_total_sets'])
]
values = ['p1_winner', 'p2_winner', 'not_applicable']

df['winner'] = np.select(conditions, values)
df = df.loc[(~df['winner'].isin(['not_applicable', '0'])), :]
df['winner'] = np.where((df['winner'] == 'p1_winner'), 1, 0)
df['winner'].value_counts()
# Out:
# 0    919
# 1    901
# Name: winner, dtype: int64

# %%
# Remove null values
df = df.drop(['calendar_year', 'p1_max_games_row', 'p2_max_games_row', 'p1_servgames_won', 
         'p2_servgames_won', 'player1_1st_set',
       'player1_2nd_set', 'player1_3rd_set', 'player1_4th_set',
       'player1_5th_set', 'player1_country', 'player1_name', 'player1_seed',
       'player1_surname', 'player1_total_sets', 'player2_1st_set',
       'player2_2nd_set', 'player2_3rd_set', 'player2_4th_set',
       'player2_5th_set', 'player2_country', 'player2_name', 'player2_seed',
       'player2_surname', 'player2_total_sets', 'tournament',
       'tournament_phase', 'p1_tiebreaks_won', 'p2_tiebreaks_won'], axis=1)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1820 entries, 0 to 1871
# Data columns (total 19 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   p1_1stserve_pwon     1034 non-null   float64
#  1   p1_1stserve_success  1034 non-null   float64
#  2   p1_2ndserve_pwon     990 non-null    float64
#  3   p1_aces              994 non-null    float64
#  4   p1_breakpoints_won   800 non-null    float64
#  5   p1_doublefaults      916 non-null    float64
#  6   p1_max_points_row    1034 non-null   float64
#  7   p1_total_games_won   1034 non-null   float64
#  8   p1_total_points_won  1034 non-null   float64
#  9   p2_1stserve_pwon     1034 non-null   float64
#  10  p2_1stserve_success  1034 non-null   float64
#  11  p2_2ndserve_pwon     990 non-null    float64
#  12  p2_aces              994 non-null    float64
#  13  p2_breakpoints_won   800 non-null    float64
#  14  p2_doublefaults      916 non-null    float64
#  15  p2_max_points_row    1034 non-null   float64
#  16  p2_total_games_won   1034 non-null   float64
#  17  p2_total_points_won  1034 non-null   float64
#  18  winner               1820 non-null   int64
# dtypes: float64(18), int64(1)
# memory usage: 284.4 KB

# %%
# Remove missing data
df = df.dropna()
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 679 entries, 0 to 1871
# Data columns (total 19 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   p1_1stserve_pwon     679 non-null    float64
#  1   p1_1stserve_success  679 non-null    float64
#  2   p1_2ndserve_pwon     679 non-null    float64
#  3   p1_aces              679 non-null    float64
#  4   p1_breakpoints_won   679 non-null    float64
#  5   p1_doublefaults      679 non-null    float64
#  6   p1_max_points_row    679 non-null    float64
#  7   p1_total_games_won   679 non-null    float64
#  8   p1_total_points_won  679 non-null    float64
#  9   p2_1stserve_pwon     679 non-null    float64
#  10  p2_1stserve_success  679 non-null    float64
#  11  p2_2ndserve_pwon     679 non-null    float64
#  12  p2_aces              679 non-null    float64
#  13  p2_breakpoints_won   679 non-null    float64
#  14  p2_doublefaults      679 non-null    float64
#  15  p2_max_points_row    679 non-null    float64
#  16  p2_total_games_won   679 non-null    float64
#  17  p2_total_points_won  679 non-null    float64
#  18  winner               679 non-null    int64
# dtypes: float64(18), int64(1)
# memory usage: 106.1 KB

# %% [markdown]
# <font size = '4'><b>Guess match winner based only on stats using Neural Network</b></font>

# %%
df.columns
# Out:
# Index(['p1_1stserve_pwon', 'p1_1stserve_success', 'p1_2ndserve_pwon',
#        'p1_aces', 'p1_breakpoints_won', 'p1_doublefaults', 'p1_max_points_row',
#        'p1_total_games_won', 'p1_total_points_won', 'p2_1stserve_pwon',
#        'p2_1stserve_success', 'p2_2ndserve_pwon', 'p2_aces',
#        'p2_breakpoints_won', 'p2_doublefaults', 'p2_max_points_row',
#        'p2_total_games_won', 'p2_total_points_won', 'winner'],
#       dtype='object')

# %%
# Define y independent variable, and X predictors
y = df['winner']

ao_predictors = [
#     'p1_1stserve_pwon', 
    'p1_1stserve_success', 
#     'p1_2ndserve_pwon',
    'p1_aces', 
    'p1_breakpoints_won', 
    'p1_doublefaults', 
#     'p1_max_points_row',
#     'p1_total_games_won', 
#     'p1_total_points_won', 
#     'p2_1stserve_pwon',
    'p2_1stserve_success', 
#     'p2_2ndserve_pwon', 
    'p2_aces',
    'p2_breakpoints_won', 
    'p2_doublefaults', 
#     'p2_max_points_row',
#     'p2_total_games_won', 
#     'p2_total_points_won'
]
X = df[ao_predictors]

# %%
# Create train and test samples
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.25,random_state=0)

# %%
# create model, add dense layers one by one specifying activation function
from keras.models import Sequential
from keras.layers import Dense, Dropout

model = Sequential()
model.add(Dense(15, input_dim=8, activation='relu')) # input layer requires input_dim param
model.add(Dense(30, activation='relu'))
model.add(Dense(15, activation='relu'))
model.add(Dense(8, activation='relu'))
model.add(Dropout(.2))
model.add(Dense(1, activation='sigmoid')) # sigmoid instead of relu for final probability between 0 and 1

# %%
# compile the model, adam gradient descent (optimized)
model.compile(loss="binary_crossentropy", optimizer="adam", metrics=['accuracy'])

# %%
# call the function to fit to the data (training the network)
model.fit(X_train, y_train, epochs = 100, batch_size=60, validation_data=(X_test, y_test))
# Out:
# Epoch 1/100
# 9/9 [==============================] - 2s 108ms/step - loss: 1.4052 - accuracy: 0.4991 - val_loss: 0.6982 - val_accuracy: 0.5882
# Epoch 2/100
# 9/9 [==============================] - 0s 17ms/step - loss: 0.9916 - accuracy: 0.5083 - val_loss: 0.6631 - val_accuracy: 0.6059
# Epoch 3/100
# 9/9 [==============================] - 0s 18ms/step - loss: 0.7583 - accuracy: 0.5602 - val_loss: 0.6365 - val_accuracy: 0.6882
# Epoch 4/100
# 9/9 [==============================] - 0s 17ms/step - loss: 0.6614 - accuracy: 0.6065 - val_loss: 0.6509 - val_accuracy: 0.6353
# Epoch 5/100
# 9/9 [==============================] - 0s 16ms/step - loss: 0.6890 - accuracy: 0.5979 - val_loss: 0.6317 - val_accuracy: 0.6765
# Epoch 6/100
# 9/9 [==============================] - 0s 23ms/step - loss: 0.6718 - accuracy: 0.6077 - val_loss: 0.5993 - val_accuracy: 0.7235
# Epoch 7/100
# 9/9 [==============================] - 0s 13ms/step - loss: 0.6330 - accuracy: 0.6702 - val_loss: 0.5904 - val_accuracy: 0.7412
# Epoch 8/100
# 9/9 [==============================] - 0s 13ms/step - loss: 0.6388 - accuracy: 0.6692 - val_loss: 0.5803 - val_accuracy: 0.7588
# Epoch 9/100
# 9/9 [==============================] - 0s 15ms/step - loss: 0.6241 - accuracy: 0.6751 - val_loss: 0.5663 - val_accuracy: 0.7647
# Epoch 10/100
# 9/9 [==============================] - 0s 15ms/step - loss: 0.5859 - accuracy: 0.7062 - val_loss: 0.5387 - val_accuracy: 0.7882
# Epoch 11/100
# 9/9 [==============================] - 0s 18ms/step - loss: 0.5578 - accuracy: 0.7518 - val_loss: 0.5025 - val_accuracy: 0.8118
# Epoch 12/100
# 9/9 [==============================] - 0s 17ms/step - loss: 0.5529 - accuracy: 0.7097 - val_loss: 0.4704 - val_accuracy: 0.8412
# Epoch 13/100
# 9/9 [==============================] - 0s 18ms/step - loss: 0.5021 - accuracy: 0.7567 - val_loss: 0.4512 - val_accuracy: 0.8529
# Epoch 14/100
# 9/9 [==============================] - 0s 18ms/step - loss: 0.5266 - accuracy: 0.7283 - val_loss: 0.4081 - val_accuracy: 0.8706
# Epoch 15/100
# 9/9 [==============================] - 0s 23ms/step - loss: 0.4898 - accuracy: 0.7314 - val_loss: 0.3906 - val_accuracy: 0.8765
# Epoch 16/100
# 9/9 [==============================] - 0s 18ms/step - loss: 0.4548 - accuracy: 0.7733 - val_loss: 0.3797 - val_accuracy: 0.8706
# Epoch 17/100
# 9/9 [==============================] - 0s 10ms/step - loss: 0.4416 - accuracy: 0.7672 - val_loss: 0.3767 - val_accuracy: 0.8706
# Epoch 18/100
# 9/9 [==============================] - 0s 11ms/step - loss: 0.4086 - accuracy: 0.7895 - val_loss: 0.3400 - val_accuracy: 0.8941
# Epoch 19/100
# 9/9 [==============================] - 0s 12ms/step - loss: 0.4039 - accuracy: 0.7961 - val_loss: 0.3258 - val_accuracy: 0.9000
# Epoch 20/100
# 9/9 [==============================] - 0s 10ms/step - loss: 0.4374 - accuracy: 0.7635 - val_loss: 0.3337 - val_accuracy: 0.8824
# Epoch 21/100
# 9/9 [==============================] - 0s 12ms/step - loss: 0.3994 - accuracy: 0.8004 - val_loss: 0.3230 - val_accuracy: 0.8882
# Epoch 22/100
# 9/9 [==============================] - 0s 10ms/step - loss: 0.3902 - accuracy: 0.7779 - val_loss: 0.4069 - val_accuracy: 0.8294
# Epoch 23/100
# 9/9 [==============================] - 0s 10ms/step - loss: 0.4123 - accuracy: 0.7744 - val_loss: 0.2955 - val_accuracy: 0.9118
# Epoch 24/100
# 9/9 [==============================] - 0s 10ms/step - loss: 0.3547 - accuracy: 0.8059 - val_loss: 0.2819 - val_accuracy: 0.9000
# Epoch 25/100
# 9/9 [==============================] - 0s 9ms/step - loss: 0.3487 - accuracy: 0.8129 - val_loss: 0.2716 - val_accuracy: 0.9118
# Epoch 26/100
# 9/9 [==============================] - 0s 12ms/step - loss: 0.3330 - accuracy: 0.8676 - val_loss: 0.2673 - val_accuracy: 0.9000
# Epoch 27/100
# 9/9 [==============================] - 0s 11ms/step - loss: 0.3313 - accuracy: 0.8627 - val_loss: 0.2663 - val_accuracy: 0.9294
# Epoch 28/100
# 9/9 [==============================] - 0s 16ms/step - loss: 0.3349 - accuracy: 0.8761 - val_loss: 0.2655 - val_accuracy: 0.9294
# Epoch 29/100
# 9/9 [==============================] - 0s 16ms/step - loss: 0.3072 - accuracy: 0.9103 - val_loss: 0.2622 - val_accuracy: 0.8941
# Epoch 30/100
# 9/9 [==============================] - 0s 16ms/step - loss: 0.2987 - accuracy: 0.8997 - val_loss: 0.2587 - val_accuracy: 0.8941
# Epoch 31/100
# 9/9 [==============================] - 0s 11ms/step - loss: 0.3328 - accuracy: 0.8479 - val_loss: 0.2553 - val_accuracy: 0.8941
# Epoch 32/100
# 9/9 [==============================] - 0s 14ms/step - loss: 0.2938 - accuracy: 0.9009 - val_loss: 0.2557 - val_accuracy: 0.8882
# Epoch 33/100
# 9/9 [==============================] - 0s 15ms/step - loss: 0.2825 - accuracy: 0.8975 - val_loss: 0.2455 - val_accuracy: 0.9000
# Epoch 34/100
# 9/9 [==============================] - 0s 15ms/step - loss: 0.2736 - accuracy: 0.9006 - val_loss: 0.2514 - val_accuracy: 0.9235
# Epoch 35/100
# 9/9 [==============================] - 0s 15ms/step - loss: 0.3357 - accuracy: 0.8648 - val_loss: 0.2445 - val_accuracy: 0.9353
# Epoch 36/100
# 9/9 [==============================] - 0s 15ms/step - loss: 0.2949 - accuracy: 0.8987 - val_loss: 0.2464 - val_accuracy: 0.9353
# Epoch 37/100
# 9/9 [==============================] - 0s 17ms/step - loss: 0.2830 - accuracy: 0.9015 - val_loss: 0.2404 - val_accuracy: 0.9118
# Epoch 38/100
# 9/9 [==============================] - 0s 16ms/step - loss: 0.2788 - accuracy: 0.8880 - val_loss: 0.2440 - val_accuracy: 0.9294
# Epoch 39/100
# 9/9 [==============================] - 0s 17ms/step - loss: 0.2897 - accuracy: 0.8799 - val_loss: 0.2384 - val_accuracy: 0.9294
# Epoch 40/100
# 9/9 [==============================] - 0s 15ms/step - loss: 0.2863 - accuracy: 0.8807 - val_loss: 0.2473 - val_accuracy: 0.9353
# Epoch 41/100
# 9/9 [==============================] - 0s 12ms/step - loss: 0.2897 - accuracy: 0.9007 - val_loss: 0.3174 - val_accuracy: 0.8706
# Epoch 42/100
# 9/9 [==============================] - 0s 11ms/step - loss: 0.2912 - accuracy: 0.8981 - val_loss: 0.2388 - val_accuracy: 0.9412
# Epoch 43/100
# 9/9 [==============================] - 0s 11ms/step - loss: 0.2820 - accuracy: 0.9002 - val_loss: 0.2325 - val_accuracy: 0.9294
# Epoch 44/100
# 9/9 [==============================] - 0s 12ms/step - loss: 0.2377 - accuracy: 0.9154 - val_loss: 0.2530 - val_accuracy: 0.8765
# Epoch 45/100
# 9/9 [==============================] - 0s 13ms/step - loss: 0.2423 - accuracy: 0.8970 - val_loss: 0.2328 - val_accuracy: 0.9118
# Epoch 46/100
# 9/9 [==============================] - 0s 16ms/step - loss: 0.2641 - accuracy: 0.9040 - val_loss: 0.2285 - val_accuracy: 0.8941
# Epoch 47/100
# 9/9 [==============================] - 0s 23ms/step - loss: 0.2527 - accuracy: 0.9307 - val_loss: 0.2284 - val_accuracy: 0.9118
# Epoch 48/100
# 9/9 [==============================] - 0s 33ms/step - loss: 0.2658 - accuracy: 0.8850 - val_loss: 0.2856 - val_accuracy: 0.8765
# Epoch 49/100
# 9/9 [==============================] - 0s 33ms/step - loss: 0.2858 - accuracy: 0.8973 - val_loss: 0.2690 - val_accuracy: 0.8706
# Epoch 50/100
# 9/9 [==============================] - 0s 26ms/step - loss: 0.3289 - accuracy: 0.8788 - val_loss: 0.2397 - val_accuracy: 0.8824
# Epoch 51/100
# 9/9 [==============================] - 0s 11ms/step - loss: 0.2454 - accuracy: 0.9081 - val_loss: 0.2357 - val_accuracy: 0.8882
# Epoch 52/100
# 9/9 [==============================] - 0s 10ms/step - loss: 0.2680 - accuracy: 0.8888 - val_loss: 0.2636 - val_accuracy: 0.9059
# Epoch 53/100
# 9/9 [==============================] - 0s 12ms/step - loss: 0.2274 - accuracy: 0.9293 - val_loss: 0.2504 - val_accuracy: 0.9294
# Epoch 54/100
# 9/9 [==============================] - 0s 13ms/step - loss: 0.2280 - accuracy: 0.9253 - val_loss: 0.2306 - val_accuracy: 0.9118
# Epoch 55/100
# 9/9 [==============================] - 0s 14ms/step - loss: 0.2388 - accuracy: 0.9120 - val_loss: 0.2293 - val_accuracy: 0.9118
# Epoch 56/100
# 9/9 [==============================] - 0s 12ms/step - loss: 0.2459 - accuracy: 0.9048 - val_loss: 0.2320 - val_accuracy: 0.8941
# Epoch 57/100
# 9/9 [==============================] - 0s 13ms/step - loss: 0.2300 - accuracy: 0.9085 - val_loss: 0.2391 - val_accuracy: 0.8765
# Epoch 58/100
# 9/9 [==============================] - 0s 11ms/step - loss: 0.2414 - accuracy: 0.9117 - val_loss: 0.2331 - val_accuracy: 0.9235
# Epoch 59/100
# 9/9 [==============================] - 0s 13ms/step - loss: 0.2469 - accuracy: 0.9105 - val_loss: 0.2330 - val_accuracy: 0.9059
# Epoch 60/100
# 9/9 [==============================] - 0s 11ms/step - loss: 0.2380 - accuracy: 0.9128 - val_loss: 0.2345 - val_accuracy: 0.9176
# Epoch 61/100
# 9/9 [==============================] - 0s 12ms/step - loss: 0.2280 - accuracy: 0.9252 - val_loss: 0.2465 - val_accuracy: 0.9294
# Epoch 62/100
# 9/9 [==============================] - 0s 10ms/step - loss: 0.2599 - accuracy: 0.9188 - val_loss: 0.2436 - val_accuracy: 0.8882
# Epoch 63/100
# 9/9 [==============================] - 0s 10ms/step - loss: 0.2583 - accuracy: 0.9091 - val_loss: 0.2493 - val_accuracy: 0.8882
# Epoch 64/100
# 9/9 [==============================] - 0s 17ms/step - loss: 0.2393 - accuracy: 0.9174 - val_loss: 0.2400 - val_accuracy: 0.8824
# Epoch 65/100
# 9/9 [==============================] - 0s 16ms/step - loss: 0.2381 - accuracy: 0.9162 - val_loss: 0.2657 - val_accuracy: 0.9118
# Epoch 66/100
# 9/9 [==============================] - 0s 17ms/step - loss: 0.2397 - accuracy: 0.9149 - val_loss: 0.2359 - val_accuracy: 0.9059
# Epoch 67/100
# 9/9 [==============================] - 0s 16ms/step - loss: 0.2241 - accuracy: 0.9295 - val_loss: 0.2414 - val_accuracy: 0.8765
# Epoch 68/100
# 9/9 [==============================] - 0s 17ms/step - loss: 0.2487 - accuracy: 0.9252 - val_loss: 0.2352 - val_accuracy: 0.9000
# Epoch 69/100
# 9/9 [==============================] - 0s 15ms/step - loss: 0.2411 - accuracy: 0.8944 - val_loss: 0.3150 - val_accuracy: 0.8765
# Epoch 70/100
# 9/9 [==============================] - 0s 16ms/step - loss: 0.3151 - accuracy: 0.8978 - val_loss: 0.2366 - val_accuracy: 0.9000
# Epoch 71/100
# 9/9 [==============================] - 0s 16ms/step - loss: 0.1952 - accuracy: 0.9497 - val_loss: 0.2376 - val_accuracy: 0.9294
# Epoch 72/100
# 9/9 [==============================] - 0s 16ms/step - loss: 0.2318 - accuracy: 0.9214 - val_loss: 0.2325 - val_accuracy: 0.9059
# Epoch 73/100
# 9/9 [==============================] - 0s 16ms/step - loss: 0.2036 - accuracy: 0.9413 - val_loss: 0.2406 - val_accuracy: 0.8882
# Epoch 74/100
# 9/9 [==============================] - 0s 16ms/step - loss: 0.2072 - accuracy: 0.9275 - val_loss: 0.2319 - val_accuracy: 0.9059
# Epoch 75/100
# 9/9 [==============================] - 0s 25ms/step - loss: 0.2442 - accuracy: 0.9040 - val_loss: 0.2632 - val_accuracy: 0.9118
# Epoch 76/100
# 9/9 [==============================] - 0s 14ms/step - loss: 0.2425 - accuracy: 0.9153 - val_loss: 0.2417 - val_accuracy: 0.9235
# Epoch 77/100
# 9/9 [==============================] - 0s 9ms/step - loss: 0.2361 - accuracy: 0.9118 - val_loss: 0.2420 - val_accuracy: 0.8824
# Epoch 78/100
# 9/9 [==============================] - 0s 10ms/step - loss: 0.2410 - accuracy: 0.9175 - val_loss: 0.2448 - val_accuracy: 0.9176
# Epoch 79/100
# 9/9 [==============================] - 0s 13ms/step - loss: 0.2085 - accuracy: 0.9277 - val_loss: 0.2307 - val_accuracy: 0.9176
# Epoch 80/100
# 9/9 [==============================] - 0s 10ms/step - loss: 0.2147 - accuracy: 0.9209 - val_loss: 0.2362 - val_accuracy: 0.9235
# Epoch 81/100
# 9/9 [==============================] - 0s 14ms/step - loss: 0.2508 - accuracy: 0.9291 - val_loss: 0.2494 - val_accuracy: 0.8824
# Epoch 82/100
# 9/9 [==============================] - 0s 12ms/step - loss: 0.2300 - accuracy: 0.9249 - val_loss: 0.2407 - val_accuracy: 0.8824
# Epoch 83/100
# 9/9 [==============================] - 0s 12ms/step - loss: 0.2084 - accuracy: 0.9297 - val_loss: 0.2373 - val_accuracy: 0.9059
# Epoch 84/100
# 9/9 [==============================] - 0s 12ms/step - loss: 0.2464 - accuracy: 0.9089 - val_loss: 0.2391 - val_accuracy: 0.9176
# Epoch 85/100
# 9/9 [==============================] - 0s 17ms/step - loss: 0.2099 - accuracy: 0.9309 - val_loss: 0.2392 - val_accuracy: 0.9294
# Epoch 86/100
# 9/9 [==============================] - 0s 22ms/step - loss: 0.2225 - accuracy: 0.9169 - val_loss: 0.2351 - val_accuracy: 0.8882
# Epoch 87/100
# 9/9 [==============================] - 0s 17ms/step - loss: 0.2066 - accuracy: 0.9253 - val_loss: 0.2343 - val_accuracy: 0.9059
# Epoch 88/100
# 9/9 [==============================] - 0s 20ms/step - loss: 0.2171 - accuracy: 0.9354 - val_loss: 0.2506 - val_accuracy: 0.9235
# Epoch 89/100
# 9/9 [==============================] - 0s 18ms/step - loss: 0.2160 - accuracy: 0.9271 - val_loss: 0.2481 - val_accuracy: 0.8824
# Epoch 90/100
# 9/9 [==============================] - 0s 17ms/step - loss: 0.2393 - accuracy: 0.9151 - val_loss: 0.2365 - val_accuracy: 0.9059
# Epoch 91/100
# 9/9 [==============================] - 0s 17ms/step - loss: 0.1946 - accuracy: 0.9392 - val_loss: 0.2357 - val_accuracy: 0.9118
# Epoch 92/100
# 9/9 [==============================] - 0s 30ms/step - loss: 0.1906 - accuracy: 0.9436 - val_loss: 0.2628 - val_accuracy: 0.9235
# Epoch 93/100
# 9/9 [==============================] - 0s 27ms/step - loss: 0.2752 - accuracy: 0.9201 - val_loss: 0.2364 - val_accuracy: 0.9059
# Epoch 94/100
# 9/9 [==============================] - 0s 18ms/step - loss: 0.2188 - accuracy: 0.9161 - val_loss: 0.2595 - val_accuracy: 0.9176
# Epoch 95/100
# 9/9 [==============================] - 0s 18ms/step - loss: 0.2585 - accuracy: 0.9225 - val_loss: 0.2599 - val_accuracy: 0.9235
# Epoch 96/100
# 9/9 [==============================] - 0s 18ms/step - loss: 0.2377 - accuracy: 0.9227 - val_loss: 0.2429 - val_accuracy: 0.8882
# Epoch 97/100
# 9/9 [==============================] - 0s 17ms/step - loss: 0.2320 - accuracy: 0.9270 - val_loss: 0.2550 - val_accuracy: 0.8824
# Epoch 98/100
# 9/9 [==============================] - 0s 19ms/step - loss: 0.2132 - accuracy: 0.9355 - val_loss: 0.2554 - val_accuracy: 0.9176
# Epoch 99/100
# 9/9 [==============================] - 0s 16ms/step - loss: 0.2257 - accuracy: 0.9281 - val_loss: 0.2373 - val_accuracy: 0.8941
# Epoch 100/100
# 9/9 [==============================] - 0s 16ms/step - loss: 0.2199 - accuracy: 0.9154 - val_loss: 0.2544 - val_accuracy: 0.8765

# %%
# save the model
model.save('ao_nn')
# Out:
# INFO:tensorflow:Assets written to: ao_nn/assets

# %% [markdown]
# <font size = '4'><b>Apply AO trained model to US Open database to evaluate performance</b></font>

# %%
# The Objective is to check if the model trained with Austalian Open data can be used for the US Open
#Load parsed US Open Data
url = "https://raw.githubusercontent.com/ftkdev/ao_scraper_project/master/australian_open/extracts/usdata_final.csv"
df_us = pd.read_csv(url)
df_us = df_us.reindex(sorted(df_us.columns), axis=1)
df_us.shape
# Out:
# (1531, 47)

# %%
#Prepare database with same previous steps used above for AO db
# Fix calendar_year column
df_us['calendar_year'] = df_us['calendar_year'].str.replace('[', '', regex=True).str.replace(']', '', regex=True).astype(int)

#Create dependent variable y (winner)
conditions = [
    (df_us['player1_total_sets'] > df_us['player2_total_sets']),
    (df_us['player1_total_sets'] < df_us['player2_total_sets']),
    (df_us['player1_total_sets'] == df_us['player2_total_sets'])
]
values = ['p1_winner', 'p2_winner', 'not_applicable']

df_us['winner'] = np.select(conditions, values)
df_us = df_us.loc[(~df_us['winner'].isin(['not_applicable', '0'])), :]

# Remove null values
df_us = df_us.drop(['calendar_year', 'p1_max_games_row', 'p2_max_games_row', 'p1_servgames_won', 
         'p2_servgames_won', 'player1_1st_set',
       'player1_2nd_set', 'player1_3rd_set', 'player1_4th_set',
       'player1_5th_set', 'player1_country', 'player1_name', 'player1_seed',
       'player1_surname', 'player1_total_sets', 'player2_1st_set',
       'player2_2nd_set', 'player2_3rd_set', 'player2_4th_set',
       'player2_5th_set', 'player2_country', 'player2_name', 'player2_seed',
       'player2_surname', 'player2_total_sets', 'tournament',
       'tournament_phase', 'p1_tiebreaks_won', 'p2_tiebreaks_won'], axis=1)

df_us = df_us.dropna()

# %%
# Separate US Open samples to run in the model
y_us = df_us['winner']
y_us = np.where(y_us == 'p1_winner', 1, 0)
X_us = df_us[ao_predictors]

# %%
from tensorflow import keras
model_load = keras.models.load_model('ao_nn')

# %%
# summarize model.
model_load.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 15)                135
# _________________________________________________________________
# dense_1 (Dense)              (None, 30)                480
# _________________________________________________________________
# dense_2 (Dense)              (None, 15)                465
# _________________________________________________________________
# dense_3 (Dense)              (None, 8)                 128
# _________________________________________________________________
# dropout (Dropout)            (None, 8)                 0
# _________________________________________________________________
# dense_4 (Dense)              (None, 1)                 9
# =================================================================
# Total params: 1,217
# Trainable params: 1,217
# Non-trainable params: 0
# _________________________________________________________________

# %%
score = model_load.evaluate(X_us, y_us, verbose=0)
print("%s: %.2f%%" % (model_load.metrics_names[1], score[1]*100))
# Out:
# accuracy: 90.55%

# %%
y_pred = model.predict(X_us)
y_pred
# Out:
# array([[0.04495621],
#        [0.04428926],
#        [0.9910822 ],
#        [0.01041132],
#        [0.03460088],
#        [0.9953807 ],
#        [0.49574476],
#        [0.12215248],
#        [0.08008137],
#        [0.9931527 ],
#        [0.01686895],
#        [0.03902355],
#        [0.03890383],
#        [0.99848497],
#        [0.984118  ],
#        [0.22252035],
#        [0.9950516 ],
#        [0.9738406 ],
#        [0.95997155],
#        [0.05269024],
#        [0.02278247],
#        [0.6234812 ],
#        [0.09652802],
#        [0.00909728],
#        [0.40687442],
#        [0.01833224],
#        [0.99876887],
#        [0.9998218 ],
#        [0.96324646],
#        [0.01051062],
#        [0.00290686],
#        [0.07291999],
#        [0.6133333 ],
#        [0.05889943],
#        [0.9951953 ],
#        [0.97295547],
#        [0.92409813],
#        [0.03484595],
#        [0.9968079 ],
#        [0.01442748],
#        [0.04376844],
#        [0.89682686],
#        [0.13983822],
#        [0.9977626 ],
#        [0.9977319 ],
#        [0.9989053 ],
#        [0.03816649],
#        [0.07563034],
#        [0.02605721],
#        [0.99961555],
#        [0.20120513],
#        [0.08208981],
#        [0.01119733],
#        [0.01344618],
#        [0.99880767],
#        [0.98679954],
#        [0.2074242 ],
#        [0.99771285],
#        [0.9970531 ],
#        [0.9971775 ],
#        [0.89186466],
#        [0.9960836 ],
#        [0.04888931],
#        [0.9657161 ],
#        [0.9970882 ],
#        [0.03046402],
#        [0.63657933],
#        [0.994943  ],
#        [0.9956862 ],
#        [0.9329268 ],
#        [0.967041  ],
#        [0.03562373],
#        [0.06135634],
#        [0.99989456],
#        [0.9797701 ],
#        [0.999056  ],
#        [0.03373626],
#        [0.16688007],
#        [0.0861145 ],
#        [0.3964818 ],
#        [0.9999132 ],
#        [0.02148673],
#        [0.0465745 ],
#        [0.23098356],
#        [0.98781395],
#        [0.03926983],
#        [0.99454296],
#        [0.8504994 ],
#        [0.98893446],
#        [0.05171552],
#        [0.99962413],
#        [0.99968827],
#        [0.01797038],
#        [0.05322376],
#        [0.9941126 ],
#        [0.9977435 ],
#        [0.9984992 ],
#        [0.99458236],
#        [0.97718847],
#        [0.9912159 ],
#        [0.8871736 ],
#        [0.3327037 ],
#        [0.98990387],
#        [0.07175407],
#        [0.09280241],
#        [0.9653295 ],
#        [0.078199  ],
#        [0.99946487],
#        [0.99542284],
#        [0.9892109 ],
#        [0.9732352 ],
#        [0.9975852 ],
#        [0.99985766],
#        [0.93920654],
#        [0.9796324 ],
#        [0.04475218],
#        [0.9992186 ],
#        [0.0183188 ],
#        [0.22777519],
#        [0.04928604],
#        [0.05169562],
#        [0.12064853],
#        [0.99874693],
#        [0.01038015],
#        [0.9644345 ],
#        [0.99924314],
#        [0.94372094],
#        [0.15034437],
#        [0.9994043 ],
#        [0.9415648 ],
#        [0.02536854],
#        [0.9971354 ],
#        [0.05087534],
#        [0.12982929],
#        [0.9998225 ],
#        [0.9774593 ],
#        [0.99989724],
#        [0.38500798],
#        [0.99987006],
#        [0.01596037],
#        [0.9025972 ],
#        [0.9989327 ],
#        [0.99748284],
#        [0.2224972 ],
#        [0.9928175 ],
#        [0.04044619],
#        [0.8473752 ],
#        [0.06341949],
#        [0.9966884 ],
#        [0.676158  ],
#        [0.0737626 ],
#        [0.9994265 ],
#        [0.08327213],
#        [0.01377511],
#        [0.02940616],
#        [0.99893695],
#        [0.03491396],
#        [0.9936414 ],
#        [0.99720526],
#        [0.86500394],
#        [0.99904454],
#        [0.13129723],
#        [0.08444506],
#        [0.99054253],
#        [0.9907379 ],
#        [0.7013129 ],
#        [0.9999913 ],
#        [0.1023047 ],
#        [0.08719262],
#        [0.95747495],
#        [0.01409861],
#        [0.99915   ],
#        [0.07859764],
#        [0.03190365],
#        [0.9992453 ],
#        [0.98746145],
#        [0.9999181 ],
#        [0.241469  ],
#        [0.07307675],
#        [0.05030701],
#        [0.05566448],
#        [0.02707902],
#        [0.97095865],
#        [0.9611467 ],
#        [0.03506455],
#        [0.07199511],
#        [0.29692656],
#        [0.83315116],
#        [0.9873315 ],
#        [0.9947288 ],
#        [0.03529677],
#        [0.9999399 ],
#        [0.99947524],
#        [0.01330891],
#        [0.47266498],
#        [0.97725374],
#        [0.02826476],
#        [0.99210846],
#        [0.4448531 ],
#        [0.9961815 ],
#        [0.05641919],
#        [0.091791  ],
#        [0.13653085],
#        [0.08795038],
#        [0.07303089],
#        [0.11363974],
#        [0.99677104],
#        [0.03219861],
#        [0.02061841],
#        [0.9829656 ],
#        [0.999848  ],
#        [0.9970549 ],
#        [0.02062339],
#        [0.93458295],
#        [0.99732244],
#        [0.06683025],
#        [0.10591221],
#        [0.00896442],
#        [0.9994303 ],
#        [0.02515751],
#        [0.97477615],
#        [0.01689371],
#        [0.9293048 ],
#        [0.9849701 ],
#        [0.01871827],
#        [0.9990152 ],
#        [0.04727319],
#        [0.99994975],
#        [0.9970287 ],
#        [0.7764815 ],
#        [0.03017396],
#        [0.3354075 ],
#        [0.05784917],
#        [0.23511764],
#        [0.9986594 ],
#        [0.20827672],
#        [0.9998671 ],
#        [0.24440426],
#        [0.706561  ],
#        [0.99969685],
#        [0.06992763],
#        [0.13354889],
#        [0.12934113],
#        [0.9829948 ],
#        [0.530268  ],
#        [0.9852543 ],
#        [0.99481165],
#        [0.9903232 ],
#        [0.95813173],
#        [0.2693562 ],
#        [0.9091146 ],
#        [0.72024965],
#        [0.98947525],
#        [0.0968436 ],
#        [0.9996108 ],
#        [0.99642384],
#        [0.10418162],
#        [0.6718728 ],
#        [0.01548019],
#        [0.996595  ],
#        [0.99509513],
#        [0.09862044],
#        [0.99899936],
#        [0.9992366 ],
#        [0.9305291 ],
#        [0.14001945],
#        [0.03119656],
#        [0.9972666 ],
#        [0.94030094],
#        [0.9992369 ],
#        [0.9978606 ],
#        [0.97623384],
#        [0.9997685 ],
#        [0.99827254],
#        [0.9996381 ],
#        [0.99394864],
#        [0.9991775 ],
#        [0.04685724],
#        [0.40527797],
#        [0.999483  ],
#        [0.92894423],
#        [0.99947786],
#        [0.99758947],
#        [0.98509574],
#        [0.03907779],
#        [0.3183297 ],
#        [0.99751335],
#        [0.06426865],
#        [0.0228458 ],
#        [0.9936775 ],
#        [0.7965516 ],
#        [0.995503  ],
#        [0.20968193],
#        [0.9958605 ],
#        [0.9956379 ],
#        [0.9995612 ],
#        [0.47381723],
#        [0.12481582],
#        [0.9999062 ],
#        [0.97633183],
#        [0.9044425 ],
#        [0.11623964],
#        [0.9979073 ],
#        [0.99538565],
#        [0.01030016],
#        [0.9933425 ],
#        [0.9999807 ],
#        [0.031766  ],
#        [0.01634228],
#        [0.03383213],
#        [0.06678468],
#        [0.996339  ],
#        [0.01223287],
#        [0.9997593 ],
#        [0.99990666],
#        [0.9195673 ],
#        [0.23353079],
#        [0.258856  ],
#        [0.9979699 ],
#        [0.97652423],
#        [0.99903786],
#        [0.96307886],
#        [0.99948525],
#        [0.03021902],
#        [0.95896375],
#        [0.99926716],
#        [0.96039665],
#        [0.9992967 ],
#        [0.99906063],
#        [0.99844074],
#        [0.98001957],
#        [0.6785282 ],
#        [0.06785583],
#        [0.9632368 ],
#        [0.99918485],
#        [0.09661987],
#        [0.9775212 ],
#        [0.9977731 ],
#        [0.66520435],
#        [0.65840065],
#        [0.0584614 ],
#        [0.9152137 ],
#        [0.49561128],
#        [0.22588173],
#        [0.04348278],
#        [0.16063973],
#        [0.9887697 ],
#        [0.15851009],
#        [0.06524566],
#        [0.98444796],
#        [0.9147858 ],
#        [0.9821266 ],
#        [0.9035709 ],
#        [0.10743734],
#        [0.8256813 ],
#        [0.7862561 ],
#        [0.02731431],
#        [0.07740679],
#        [0.864814  ],
#        [0.9775931 ],
#        [0.91543174],
#        [0.4054541 ],
#        [0.607316  ],
#        [0.06539455],
#        [0.09374076],
#        [0.03029585],
#        [0.09860465],
#        [0.9959781 ],
#        [0.30022052],
#        [0.2549153 ],
#        [0.96426344],
#        [0.02175882],
#        [0.0462051 ],
#        [0.01591346],
#        [0.11756155],
#        [0.01801783],
#        [0.05201346],
#        [0.07304695],
#        [0.01403713],
#        [0.0185422 ],
#        [0.11874503],
#        [0.94846624],
#        [0.705585  ],
#        [0.06948689],
#        [0.0069136 ],
#        [0.02836838],
#        [0.07714334],
#        [0.04730386],
#        [0.0673708 ],
#        [0.9046699 ],
#        [0.6458106 ],
#        [0.89265   ],
#        [0.52333325],
#        [0.08098727],
#        [0.04952326],
#        [0.99338466],
#        [0.99905944],
#        [0.9969115 ],
#        [0.9935417 ],
#        [0.9913285 ],
#        [0.0443202 ],
#        [0.99828523],
#        [0.25602257],
#        [0.999537  ],
#        [0.04764047],
#        [0.9960418 ],
#        [0.906986  ],
#        [0.99275756],
#        [0.5658957 ],
#        [0.74021345],
#        [0.9995487 ],
#        [0.9997153 ],
#        [0.02685732],
#        [0.02697945],
#        [0.24571708],
#        [0.9998969 ],
#        [0.06651437],
#        [0.19025302],
#        [0.03660658],
#        [0.99689543],
#        [0.02664125],
#        [0.99980736],
#        [0.1382201 ],
#        [0.72048384],
#        [0.9974264 ],
#        [0.02096915],
#        [0.03727689],
#        [0.9839891 ],
#        [0.4452049 ],
#        [0.9958135 ],
#        [0.99996495],
#        [0.98006076],
#        [0.99229014],
#        [0.06586793],
#        [0.9855616 ],
#        [0.9998433 ],
#        [0.71904135],
#        [0.99996555],
#        [0.04409355],
#        [0.99297667],
#        [0.9993185 ],
#        [0.98865867],
#        [0.02986673],
#        [0.99782956],
#        [0.12209329],
#        [0.9163611 ],
#        [0.99536633],
#        [0.8788727 ],
#        [0.58011305],
#        [0.9971725 ],
#        [0.9596813 ],
#        [0.06219468],
#        [0.9802588 ],
#        [0.9934896 ],
#        [0.05354372],
#        [0.05362669],
#        [0.0350174 ],
#        [0.0732998 ],
#        [0.18192959],
#        [0.9661626 ],
#        [0.01550192],
#        [0.9848325 ],
#        [0.2865165 ],
#        [0.99187124],
#        [0.97755283],
#        [0.01236969],
#        [0.98716503],
#        [0.05777875],
#        [0.0476456 ],
#        [0.19479647],
#        [0.9959439 ],
#        [0.07977584],
#        [0.99798954],
#        [0.99993443],
#        [0.9994377 ],
#        [0.03585774],
#        [0.05824059],
#        [0.0711534 ],
#        [0.99990606],
#        [0.01558903],
#        [0.06842205],
#        [0.9993239 ],
#        [0.26430848],
#        [0.9838251 ],
#        [0.0164701 ],
#        [0.03432336],
#        [0.999406  ],
#        [0.96258366],
#        [0.08407319],
#        [0.6246776 ],
#        [0.98455715],
#        [0.04311007],
#        [0.9907168 ],
#        [0.99797463],
#        [0.9968027 ],
#        [0.2423347 ],
#        [0.96992517],
#        [0.99933565],
#        [0.9956621 ],
#        [0.02673072],
#        [0.9995699 ],
#        [0.96243393],
#        [0.06606638],
#        [0.9992033 ],
#        [0.9928374 ],
#        [0.9901271 ],
#        [0.99744797],
#        [0.0273965 ],
#        [0.01889655],
#        [0.94666743],
#        [0.99937105],
#        [0.02883419],
#        [0.98648065],
#        [0.99651086],
#        [0.82388055],
#        [0.04646978],
#        [0.12229767],
#        [0.8199321 ],
#        [0.01621714],
#        [0.19003057],
#        [0.99883014],
#        [0.08624747],
#        [0.95062506],
#        [0.06636289],
#        [0.05150959],
#        [0.99919987],
#        [0.99916875],
#        [0.82484126],
#        [0.01008582],
#        [0.7549292 ],
#        [0.0222131 ],
#        [0.02612621],
#        [0.29896957],
#        [0.9402516 ],
#        [0.99982595],
#        [0.02625802],
#        [0.02185547],
#        [0.00482473],
#        [0.99968636],
#        [0.09298334],
#        [0.01930323],
#        [0.04118237],
#        [0.01135546],
#        [0.93654275],
#        [0.01750797],
#        [0.04919058],
#        [0.30153325],
#        [0.9551451 ],
#        [0.04332384],
#        [0.20658061],
#        [0.10203364],
#        [0.06470218],
#        [0.9934826 ],
#        [0.66549045],
#        [0.15908107],
#        [0.98568374],
#        [0.9754195 ],
#        [0.0606254 ],
#        [0.572073  ],
#        [0.8410021 ],
#        [0.80409616],
#        [0.9496069 ],
#        [0.9879975 ],
#        [0.38283342],
#        [0.05358472],
#        [0.36745524],
#        [0.10444522],
#        [0.98596144],
#        [0.8367036 ],
#        [0.5154644 ],
#        [0.9984963 ],
#        [0.96907866],
#        [0.12134644],
#        [0.9557796 ],
#        [0.13962442],
#        [0.07960001],
#        [0.21167523],
#        [0.8503071 ],
#        [0.9744185 ],
#        [0.69295096],
#        [0.6499618 ],
#        [0.24647906],
#        [0.58761287],
#        [0.7341885 ],
#        [0.20824248],
#        [0.0998669 ],
#        [0.92963254],
#        [0.12485111],
#        [0.93467814],
#        [0.21111122],
#        [0.27088687],
#        [0.10186982],
#        [0.3247581 ],
#        [0.19744211],
#        [0.9630935 ],
#        [0.30415255],
#        [0.14281774],
#        [0.30240294],
#        [0.9267887 ],
#        [0.15258819],
#        [0.9522032 ],
#        [0.29211855],
#        [0.65987587],
#        [0.5272086 ],
#        [0.9545063 ],
#        [0.9866174 ],
#        [0.26205802],
#        [0.4675327 ],
#        [0.8320133 ],
#        [0.9707389 ],
#        [0.39526752],
#        [0.03354862],
#        [0.03428814],
#        [0.99752545],
#        [0.86652505],
#        [0.9752784 ],
#        [0.997253  ],
#        [0.9521009 ],
#        [0.8749762 ],
#        [0.89862525],
#        [0.95551205],
#        [0.13912287],
#        [0.07474041],
#        [0.99687666],
#        [0.10765025],
#        [0.8820801 ],
#        [0.99239933],
#        [0.9947152 ],
#        [0.54917425],
#        [0.9996618 ],
#        [0.02048859],
#        [0.07307598],
#        [0.8668043 ],
#        [0.02837324],
#        [0.6419342 ],
#        [0.9997518 ],
#        [0.07755852],
#        [0.9995057 ],
#        [0.8384991 ],
#        [0.9970155 ],
#        [0.9882262 ],
#        [0.9971496 ],
#        [0.00935498],
#        [0.00813359],
#        [0.07557666],
#        [0.9501664 ],
#        [0.07503629],
#        [0.99144834],
#        [0.02706623],
#        [0.39804354],
#        [0.92824906],
#        [0.977323  ],
#        [0.9997698 ],
#        [0.02118939],
#        [0.8874953 ],
#        [0.21486962],
#        [0.34349588],
#        [0.9991325 ],
#        [0.9998029 ],
#        [0.9333316 ],
#        [0.9857513 ],
#        [0.9998247 ],
#        [0.11441576],
#        [0.01710573],
#        [0.67082834],
#        [0.99060476],
#        [0.9025437 ],
#        [0.784618  ],
#        [0.07048753],
#        [0.01116288],
#        [0.99987805],
#        [0.07304117],
#        [0.6707172 ],
#        [0.20671943],
#        [0.04301706],
#        [0.06215167],
#        [0.8155956 ],
#        [0.02183795],
#        [0.9887288 ],
#        [0.9966807 ],
#        [0.3695227 ],
#        [0.06235671],
#        [0.21285713],
#        [0.994111  ],
#        [0.9993397 ],
#        [0.03288108],
#        [0.0519563 ],
#        [0.80897856],
#        [0.03457531],
#        [0.04563442],
#        [0.99988425],
#        [0.08298507],
#        [0.6003273 ],
#        [0.03751481],
#        [0.10023937],
#        [0.9999028 ],
#        [0.514957  ],
#        [0.58744603],
#        [0.99724185],
#        [0.12127134],
#        [0.9995068 ],
#        [0.00223985],
#        [0.06300953],
#        [0.986847  ],
#        [0.019759  ],
#        [0.976742  ],
#        [0.9990115 ],
#        [0.02759609],
#        [0.99557436]], dtype=float32)
